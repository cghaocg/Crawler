# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import openpyxl
from openpyxl import Workbook
import time as tm
from time import time, strftime, localtime
import random

g_li_columnName = ['ISIN Code', 'Issuer Name', 'Security Type', 'FX', 'Term']

# %%
def check_target_url(soup, li_columnName):
    # 檢查是否為目標頁面
    is_target = False
    if len(soup.find_all('th')) == 5:
        num = 0
        is_target = True
        
        for col in soup.find_all('th'):
            if col.text.strip() != li_columnName[num]:
                is_target = False
                break
            num += 1
            
    return is_target

# %%
def list_and_crawl(host, path):
    #tm.sleep(random.uniform(1.5, 4)) # 停頓，防止網頁阻擋
    resp = requests.get(host + path)
    
    if resp.status_code == requests.codes.ok:
        soup = BeautifulSoup(resp.text, 'lxml')
        
        if check_target_url(soup, g_li_columnName):
        # 如果為目標頁：進行爬取
            print("目標頁面，進行爬取：[" + resp.url + "]")
            
            num = 0
            for data in soup.find_all('td'):
                num += 1
                remain = num % 5  # 取餘數
                
                data = data.text.strip()

                if remain == 1:
                    columnA = data
                elif remain == 2:
                    columnB = data
                elif remain == 3:
                    columnC = data
                elif remain == 4:
                    columnD = data
                elif remain == 0:
                    columnE = data
                    sheet.append([columnA, columnB, columnC, columnD, columnE])

            print("完成爬取頁面：[" + resp.url + "]")

        else:
            if soup.find("h2").text == "Networked International Securities Identification Number Data Record":
            # 如果為獨立頁：進行爬取
                print("獨立頁面，進行爬取：[" + resp.url + "]")
            
                num = 0
                for data in soup.find_all('td'):
                    num += 1

                    data = data.text.strip()

                    if num == 2:
                        columnA = data
                    elif num == 4:
                        columnD = data
                    elif num == 6:
                        columnC = data
                    elif num == 8:
                        columnE = data
                    elif num == 16:
                        columnB = data
                        sheet.append([columnA, columnB, columnC, columnD, columnE])
                        
                print("完成爬取頁面：[" + resp.url + "]")
            
            else:
            # 如果為列表頁：迴圈跑列表的 url，並呼叫自己，往下一頁
                us_url = soup.select('a[href^="/ISIN/prefix/US"]')
                for u in us_url:
                    print("處理 url：" + u.get('href'))
                    list_and_crawl(host, u.get('href'))
                
    else:
        print("response code is NOT OK, code:[" + resp.status_code + "]")

# %%
#====================== 匯出 excel 設定

# 用python建立一個Excel空白活頁簿
excel_file = Workbook()

# 建立一個工作表
sheet = excel_file.active

# 先填入第一列的欄位名稱
sheet['A1'] = 'ISIN Code'
sheet['B1'] = 'Issuer Name'
sheet['C1'] = 'Security Type'
sheet['D1'] = 'FX'
sheet['E1'] = 'Term'

# %%
print("開始爬取 [http://www.isinlei.com/ISIN/prefix/US]，開始時間：", strftime("%Y-%m-%d %H:%M:%S", localtime()))
t0 = time()
list_and_crawl("http://www.isinlei.com", "/ISIN/prefix/US") #http://www.isinlei.com/ISIN/prefix/US
print('花費時間： %0.3fs' % (time() - t0), strftime("%Y-%m-%d %H:%M:%S", localtime()))
# Out:
# 開始爬取 [http://www.isinlei.com/ISIN/prefix/US]，開始時間： 2020-04-12 00:40:58
# 處理 url：/ISIN/prefix/US0
# 處理 url：/ISIN/prefix/US00
# 處理 url：/ISIN/prefix/US000
# 處理 url：/ISIN/prefix/US0002
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0002]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0002]
# 處理 url：/ISIN/prefix/US0003
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0003]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0003]
# 處理 url：/ISIN/prefix/US0007
# 處理 url：/ISIN/prefix/US00075
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US00075]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US00075]
# 處理 url：/ISIN/prefix/US00077
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US00077]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US00077]
# 處理 url：/ISIN/prefix/US00078
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US00078]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US00078]
# 處理 url：/ISIN/prefix/US00079
# 處理 url：/ISIN/prefix/US00079C
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US00079C]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US00079C]
# 處理 url：/ISIN/prefix/US00079F
# 處理 url：/ISIN/prefix/US00079FE
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US00079FE]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US00079FE]
# 處理 url：/ISIN/prefix/US00079FH
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US00079FH]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US00079FH]
# 處理 url：/ISIN/prefix/US00079FJ
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US00079FJ]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US00079FJ]
# 處理 url：/ISIN/prefix/US00079FK
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US00079FK]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US00079FK]
# 處理 url：/ISIN/prefix/US00079FL
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US00079FL]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US00079FL]
# 處理 url：/ISIN/prefix/US00079FM
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US00079FM]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US00079FM]
# 處理 url：/ISIN/prefix/US00079FN
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US00079FN]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US00079FN]
# 處理 url：/ISIN/prefix/US00079FP
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US00079FP]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US00079FP]
# 處理 url：/ISIN/prefix/US00079FQ
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US00079FQ]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US00079FQ]
# 處理 url：/ISIN/prefix/US00079FR
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US00079FR]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US00079FR]
# 處理 url：/ISIN/prefix/US00079FS
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US00079FS]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US00079FS]
# 處理 url：/ISIN/prefix/US0007W
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0007W]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0007W]
# 處理 url：/ISIN/prefix/US0008
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0008]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0008]
# 處理 url：/ISIN/prefix/US0009
# 獨立頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0009]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0009]
# 處理 url：/ISIN/prefix/US001
# 處理 url：/ISIN/prefix/US0010
# 處理 url：/ISIN/prefix/US00101
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US00101]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US00101]
# 處理 url：/ISIN/prefix/US00103
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US00103]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US00103]
# 處理 url：/ISIN/prefix/US00104
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US00104]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US00104]
# 處理 url：/ISIN/prefix/US00105
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US00105]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US00105]
# 處理 url：/ISIN/prefix/US00108
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US00108]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US00108]
# 處理 url：/ISIN/prefix/US0010E
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0010E]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0010E]
# 處理 url：/ISIN/prefix/US0011
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0011]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0011]
# 處理 url：/ISIN/prefix/US0013
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0013]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0013]
# 處理 url：/ISIN/prefix/US0015
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0015]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0015]
# 處理 url：/ISIN/prefix/US0016
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0016]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0016]
# 處理 url：/ISIN/prefix/US0017
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0017]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0017]
# 處理 url：/ISIN/prefix/US0018
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0018]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0018]
# 處理 url：/ISIN/prefix/US0019
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0019]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0019]
# 處理 url：/ISIN/prefix/US002
# 處理 url：/ISIN/prefix/US0020
# 處理 url：/ISIN/prefix/US00202
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US00202]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US00202]
# 處理 url：/ISIN/prefix/US00203
# 獨立頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US00203]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US00203]
# 處理 url：/ISIN/prefix/US00206
# 處理 url：/ISIN/prefix/US00206H
# 獨立頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US00206H]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US00206H]
# 處理 url：/ISIN/prefix/US00206N
# 獨立頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US00206N]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US00206N]
# 處理 url：/ISIN/prefix/US00206R
# 處理 url：/ISIN/prefix/US00206R3
# 獨立頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US00206R3]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US00206R3]
# 處理 url：/ISIN/prefix/US00206RA
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US00206RA]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US00206RA]
# 處理 url：/ISIN/prefix/US00206RB
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US00206RB]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US00206RB]
# 處理 url：/ISIN/prefix/US00206RC
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US00206RC]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US00206RC]
# 處理 url：/ISIN/prefix/US00206RD
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US00206RD]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US00206RD]
# 處理 url：/ISIN/prefix/US00206RE
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US00206RE]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US00206RE]
# 處理 url：/ISIN/prefix/US00206RF
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US00206RF]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US00206RF]
# 處理 url：/ISIN/prefix/US00206RG
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US00206RG]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US00206RG]
# 處理 url：/ISIN/prefix/US00206RH
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US00206RH]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US00206RH]
# 處理 url：/ISIN/prefix/US00206RJ
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US00206RJ]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US00206RJ]
# 處理 url：/ISIN/prefix/US00207
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US00207]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US00207]
# 處理 url：/ISIN/prefix/US00208
# 獨立頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US00208]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US00208]
# 處理 url：/ISIN/prefix/US00209
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US00209]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US00209]
# 處理 url：/ISIN/prefix/US0021
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0021]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0021]
# 處理 url：/ISIN/prefix/US0023
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0023]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0023]
# 處理 url：/ISIN/prefix/US0024
# 獨立頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0024]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0024]
# 處理 url：/ISIN/prefix/US0025
# 處理 url：/ISIN/prefix/US00252
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US00252]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US00252]
# 處理 url：/ISIN/prefix/US00253
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US00253]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US00253]
# 處理 url：/ISIN/prefix/US00254
# 處理 url：/ISIN/prefix/US002545
# 獨立頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US002545]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US002545]
# 處理 url：/ISIN/prefix/US002546
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US002546]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US002546]
# 處理 url：/ISIN/prefix/US00254E
# 處理 url：/ISIN/prefix/US00254EA
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US00254EA]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US00254EA]
# 處理 url：/ISIN/prefix/US00254EB
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US00254EB]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US00254EB]
# 處理 url：/ISIN/prefix/US00254EC
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US00254EC]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US00254EC]
# 處理 url：/ISIN/prefix/US00254ED
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US00254ED]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US00254ED]
# 處理 url：/ISIN/prefix/US00254EE
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US00254EE]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US00254EE]
# 處理 url：/ISIN/prefix/US00254EF
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US00254EF]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US00254EF]
# 處理 url：/ISIN/prefix/US00254EG
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US00254EG]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US00254EG]
# 處理 url：/ISIN/prefix/US00254EH
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US00254EH]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US00254EH]
# 處理 url：/ISIN/prefix/US00254EJ
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US00254EJ]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US00254EJ]
# 處理 url：/ISIN/prefix/US00254EK
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US00254EK]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US00254EK]
# 處理 url：/ISIN/prefix/US00254EL
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US00254EL]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US00254EL]
# 處理 url：/ISIN/prefix/US00254EM
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US00254EM]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US00254EM]
# 處理 url：/ISIN/prefix/US00258
# 獨立頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US00258]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US00258]
# 處理 url：/ISIN/prefix/US0027
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0027]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0027]
# 處理 url：/ISIN/prefix/US0028
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0028]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0028]
# 處理 url：/ISIN/prefix/US0029
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0029]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0029]
# 處理 url：/ISIN/prefix/US003
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US003]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US003]
# 處理 url：/ISIN/prefix/US004
# 處理 url：/ISIN/prefix/US0040
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0040]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0040]
# 處理 url：/ISIN/prefix/US0042
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0042]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0042]
# 處理 url：/ISIN/prefix/US0043
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0043]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0043]
# 處理 url：/ISIN/prefix/US0044
# 處理 url：/ISIN/prefix/US00440
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US00440]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US00440]
# 處理 url：/ISIN/prefix/US00442
# 處理 url：/ISIN/prefix/US004421
# 處理 url：/ISIN/prefix/US004421A
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US004421A]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US004421A]
# 處理 url：/ISIN/prefix/US004421B
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US004421B]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US004421B]
# 處理 url：/ISIN/prefix/US004421C
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US004421C]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US004421C]
# 處理 url：/ISIN/prefix/US004421D
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US004421D]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US004421D]
# 處理 url：/ISIN/prefix/US004421E
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US004421E]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US004421E]
# 處理 url：/ISIN/prefix/US004421F
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US004421F]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US004421F]
# 處理 url：/ISIN/prefix/US004421G
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US004421G]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US004421G]
# 處理 url：/ISIN/prefix/US004421H
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US004421H]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US004421H]
# 處理 url：/ISIN/prefix/US004421J
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US004421J]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US004421J]
# 處理 url：/ISIN/prefix/US004421K
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US004421K]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US004421K]
# 處理 url：/ISIN/prefix/US004427
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US004427]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US004427]
# 處理 url：/ISIN/prefix/US00444
# 獨立頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US00444]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US00444]
# 處理 url：/ISIN/prefix/US00448
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US00448]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US00448]
# 處理 url：/ISIN/prefix/US0045
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0045]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0045]
# 處理 url：/ISIN/prefix/US0047
# 獨立頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0047]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0047]
# 處理 url：/ISIN/prefix/US0048
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0048]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0048]
# 處理 url：/ISIN/prefix/US005
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US005]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US005]
# 處理 url：/ISIN/prefix/US006
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US006]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US006]
# 處理 url：/ISIN/prefix/US007
# 處理 url：/ISIN/prefix/US0070
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0070]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0070]
# 處理 url：/ISIN/prefix/US0071
# 獨立頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0071]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0071]
# 處理 url：/ISIN/prefix/US0072
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0072]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0072]
# 處理 url：/ISIN/prefix/US0074
# 獨立頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0074]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0074]
# 處理 url：/ISIN/prefix/US0075
# 處理 url：/ISIN/prefix/US00751
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US00751]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US00751]
# 處理 url：/ISIN/prefix/US00755
# 處理 url：/ISIN/prefix/US00755W
# 處理 url：/ISIN/prefix/US00755WA
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US00755WA]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US00755WA]
# 處理 url：/ISIN/prefix/US00755WB
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US00755WB]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US00755WB]
# 處理 url：/ISIN/prefix/US00755WC
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US00755WC]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US00755WC]
# 處理 url：/ISIN/prefix/US00755WD
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US00755WD]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US00755WD]
# 處理 url：/ISIN/prefix/US00755WE
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US00755WE]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US00755WE]
# 處理 url：/ISIN/prefix/US00755WF
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US00755WF]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US00755WF]
# 處理 url：/ISIN/prefix/US00755WG
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US00755WG]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US00755WG]
# 處理 url：/ISIN/prefix/US00755WH
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US00755WH]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US00755WH]
# 處理 url：/ISIN/prefix/US00757
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US00757]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US00757]
# 處理 url：/ISIN/prefix/US00758
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US00758]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US00758]
# 處理 url：/ISIN/prefix/US00759
# 獨立頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US00759]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US00759]
# 處理 url：/ISIN/prefix/US0076
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0076]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0076]
# 處理 url：/ISIN/prefix/US0077
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0077]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0077]
# 處理 url：/ISIN/prefix/US0079
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0079]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0079]
# 處理 url：/ISIN/prefix/US008
# 處理 url：/ISIN/prefix/US0080
# 獨立頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0080]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0080]
# 處理 url：/ISIN/prefix/US0081
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0081]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0081]
# 處理 url：/ISIN/prefix/US0082
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0082]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0082]
# 處理 url：/ISIN/prefix/US0084
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0084]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0084]
# 處理 url：/ISIN/prefix/US0085
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0085]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0085]
# 處理 url：/ISIN/prefix/US0086
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0086]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0086]
# 處理 url：/ISIN/prefix/US0087
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0087]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0087]
# 處理 url：/ISIN/prefix/US0088
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0088]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0088]
# 處理 url：/ISIN/prefix/US0089
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0089]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0089]
# 處理 url：/ISIN/prefix/US009
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US009]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US009]
# 處理 url：/ISIN/prefix/US01
# 處理 url：/ISIN/prefix/US010
# 處理 url：/ISIN/prefix/US0101
# 處理 url：/ISIN/prefix/US01019
# 處理 url：/ISIN/prefix/US01019A
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US01019A]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US01019A]
# 處理 url：/ISIN/prefix/US01019M
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US01019M]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US01019M]
# 處理 url：/ISIN/prefix/US0102
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0102]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0102]
# 處理 url：/ISIN/prefix/US0103
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0103]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0103]
# 處理 url：/ISIN/prefix/US0106
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0106]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0106]
# 處理 url：/ISIN/prefix/US0108
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0108]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0108]
# 處理 url：/ISIN/prefix/US011
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US011]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US011]
# 處理 url：/ISIN/prefix/US012
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US012]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US012]
# 處理 url：/ISIN/prefix/US013
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US013]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US013]
# 處理 url：/ISIN/prefix/US014
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US014]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US014]
# 處理 url：/ISIN/prefix/US015
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US015]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US015]
# 處理 url：/ISIN/prefix/US016
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US016]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US016]
# 處理 url：/ISIN/prefix/US017
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US017]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US017]
# 處理 url：/ISIN/prefix/US018
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US018]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US018]
# 處理 url：/ISIN/prefix/US019
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US019]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US019]
# 處理 url：/ISIN/prefix/US01F
# 獨立頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US01F]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US01F]
# 處理 url：/ISIN/prefix/US02
# 處理 url：/ISIN/prefix/US020
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US020]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US020]
# 處理 url：/ISIN/prefix/US021
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US021]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US021]
# 處理 url：/ISIN/prefix/US022
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US022]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US022]
# 處理 url：/ISIN/prefix/US023
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US023]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US023]
# 處理 url：/ISIN/prefix/US024
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US024]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US024]
# 處理 url：/ISIN/prefix/US025
# 處理 url：/ISIN/prefix/US0255
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0255]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0255]
# 處理 url：/ISIN/prefix/US0256
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0256]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0256]
# 處理 url：/ISIN/prefix/US0258
# 處理 url：/ISIN/prefix/US02580
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US02580]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US02580]
# 處理 url：/ISIN/prefix/US02581
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US02581]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US02581]
# 處理 url：/ISIN/prefix/US02582
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US02582]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US02582]
# 處理 url：/ISIN/prefix/US02583
# 獨立頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US02583]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US02583]
# 處理 url：/ISIN/prefix/US02586
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US02586]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US02586]
# 處理 url：/ISIN/prefix/US0258M
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0258M]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0258M]
# 處理 url：/ISIN/prefix/US0259
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0259]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0259]
# 處理 url：/ISIN/prefix/US026
# 處理 url：/ISIN/prefix/US0260
# 獨立頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0260]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0260]
# 處理 url：/ISIN/prefix/US0263
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0263]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0263]
# 處理 url：/ISIN/prefix/US0264
# 獨立頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0264]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0264]
# 處理 url：/ISIN/prefix/US0266
# 處理 url：/ISIN/prefix/US02660
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US02660]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US02660]
# 處理 url：/ISIN/prefix/US02665
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US02665]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US02665]
# 處理 url：/ISIN/prefix/US02666
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US02666]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US02666]
# 處理 url：/ISIN/prefix/US0268
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0268]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0268]
# 處理 url：/ISIN/prefix/US0269
# 獨立頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0269]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0269]
# 處理 url：/ISIN/prefix/US027
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US027]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US027]
# 處理 url：/ISIN/prefix/US028
# 獨立頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US028]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US028]
# 處理 url：/ISIN/prefix/US029
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US029]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US029]
# 處理 url：/ISIN/prefix/US03
# 處理 url：/ISIN/prefix/US030
# 處理 url：/ISIN/prefix/US0300
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0300]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0300]
# 處理 url：/ISIN/prefix/US0302
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0302]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0302]
# 處理 url：/ISIN/prefix/US0303
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0303]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0303]
# 處理 url：/ISIN/prefix/US0304
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0304]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0304]
# 處理 url：/ISIN/prefix/US0306
# 處理 url：/ISIN/prefix/US03061
# 處理 url：/ISIN/prefix/US03061N
# 處理 url：/ISIN/prefix/US03061NA
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US03061NA]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US03061NA]
# 處理 url：/ISIN/prefix/US03061NB
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US03061NB]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US03061NB]
# 處理 url：/ISIN/prefix/US03061NC
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US03061NC]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US03061NC]
# 處理 url：/ISIN/prefix/US03061ND
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US03061ND]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US03061ND]
# 處理 url：/ISIN/prefix/US03061NE
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US03061NE]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US03061NE]
# 處理 url：/ISIN/prefix/US03061NF
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US03061NF]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US03061NF]
# 處理 url：/ISIN/prefix/US03061NG
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US03061NG]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US03061NG]
# 處理 url：/ISIN/prefix/US03061NH
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US03061NH]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US03061NH]
# 處理 url：/ISIN/prefix/US03063
# 獨立頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US03063]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US03063]
# 處理 url：/ISIN/prefix/US03064
# 獨立頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US03064]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US03064]
# 處理 url：/ISIN/prefix/US03066
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US03066]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US03066]
# 處理 url：/ISIN/prefix/US0307
# 處理 url：/ISIN/prefix/US03070
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US03070]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US03070]
# 處理 url：/ISIN/prefix/US03071
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US03071]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US03071]
# 處理 url：/ISIN/prefix/US03072
# 處理 url：/ISIN/prefix/US03072J
# 獨立頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US03072J]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US03072J]
# 處理 url：/ISIN/prefix/US03072S
# 處理 url：/ISIN/prefix/US03072SB
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US03072SB]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US03072SB]
# 處理 url：/ISIN/prefix/US03072SC
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US03072SC]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US03072SC]
# 處理 url：/ISIN/prefix/US03072SD
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US03072SD]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US03072SD]
# 處理 url：/ISIN/prefix/US03072SE
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US03072SE]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US03072SE]
# 處理 url：/ISIN/prefix/US03072SF
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US03072SF]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US03072SF]
# 處理 url：/ISIN/prefix/US03072SG
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US03072SG]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US03072SG]
# 處理 url：/ISIN/prefix/US03072SH
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US03072SH]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US03072SH]
# 處理 url：/ISIN/prefix/US03072SK
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US03072SK]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US03072SK]
# 處理 url：/ISIN/prefix/US03072SL
# 獨立頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US03072SL]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US03072SL]
# 處理 url：/ISIN/prefix/US03072SM
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US03072SM]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US03072SM]
# 處理 url：/ISIN/prefix/US03072SP
# 獨立頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US03072SP]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US03072SP]
# 處理 url：/ISIN/prefix/US03072SR
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US03072SR]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US03072SR]
# 處理 url：/ISIN/prefix/US03072SS
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US03072SS]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US03072SS]
# 處理 url：/ISIN/prefix/US03072SU
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US03072SU]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US03072SU]
# 處理 url：/ISIN/prefix/US03072SV
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US03072SV]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US03072SV]
# 處理 url：/ISIN/prefix/US03072SW
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US03072SW]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US03072SW]
# 處理 url：/ISIN/prefix/US03073
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US03073]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US03073]
# 處理 url：/ISIN/prefix/US03076
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US03076]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US03076]
# 處理 url：/ISIN/prefix/US03077
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US03077]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US03077]
# 處理 url：/ISIN/prefix/US03078
# 獨立頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US03078]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US03078]
# 處理 url：/ISIN/prefix/US0309
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0309]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0309]
# 處理 url：/ISIN/prefix/US031
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US031]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US031]
# 處理 url：/ISIN/prefix/US032
# 處理 url：/ISIN/prefix/US0320
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0320]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0320]
# 處理 url：/ISIN/prefix/US0321
# 處理 url：/ISIN/prefix/US03215
# 處理 url：/ISIN/prefix/US03215P
# 處理 url：/ISIN/prefix/US03215PA
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US03215PA]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US03215PA]
# 處理 url：/ISIN/prefix/US03215PB
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US03215PB]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US03215PB]
# 處理 url：/ISIN/prefix/US03215PC
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US03215PC]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US03215PC]
# 處理 url：/ISIN/prefix/US03215PD
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US03215PD]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US03215PD]
# 處理 url：/ISIN/prefix/US03215PE
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US03215PE]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US03215PE]
# 處理 url：/ISIN/prefix/US03215PF
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US03215PF]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US03215PF]
# 處理 url：/ISIN/prefix/US03216
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US03216]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US03216]
# 處理 url：/ISIN/prefix/US0323
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0323]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0323]
# 處理 url：/ISIN/prefix/US0324
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0324]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0324]
# 處理 url：/ISIN/prefix/US0325
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0325]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0325]
# 處理 url：/ISIN/prefix/US0326
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0326]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0326]
# 處理 url：/ISIN/prefix/US0328
# 獨立頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0328]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0328]
# 處理 url：/ISIN/prefix/US033
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US033]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US033]
# 處理 url：/ISIN/prefix/US034
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US034]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US034]
# 處理 url：/ISIN/prefix/US035
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US035]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US035]
# 處理 url：/ISIN/prefix/US036
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US036]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US036]
# 處理 url：/ISIN/prefix/US037
# 處理 url：/ISIN/prefix/US0373
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0373]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0373]
# 處理 url：/ISIN/prefix/US0374
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0374]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0374]
# 處理 url：/ISIN/prefix/US0375
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0375]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0375]
# 處理 url：/ISIN/prefix/US0376
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0376]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0376]
# 處理 url：/ISIN/prefix/US0377
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0377]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0377]
# 處理 url：/ISIN/prefix/US0378
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0378]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0378]
# 處理 url：/ISIN/prefix/US038
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US038]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US038]
# 處理 url：/ISIN/prefix/US039
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US039]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US039]
# 處理 url：/ISIN/prefix/US04
# 處理 url：/ISIN/prefix/US040
# 處理 url：/ISIN/prefix/US0400
# 獨立頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0400]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0400]
# 處理 url：/ISIN/prefix/US0401
# 處理 url：/ISIN/prefix/US04010
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US04010]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US04010]
# 處理 url：/ISIN/prefix/US04011
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US04011]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US04011]
# 處理 url：/ISIN/prefix/US04013
# 獨立頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US04013]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US04013]
# 處理 url：/ISIN/prefix/US04014
# 獨立頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US04014]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US04014]
# 處理 url：/ISIN/prefix/US0403
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0403]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0403]
# 處理 url：/ISIN/prefix/US0404
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0404]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0404]
# 處理 url：/ISIN/prefix/US0405
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0405]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0405]
# 處理 url：/ISIN/prefix/US0406
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0406]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0406]
# 處理 url：/ISIN/prefix/US041
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US041]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US041]
# 處理 url：/ISIN/prefix/US042
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US042]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US042]
# 處理 url：/ISIN/prefix/US043
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US043]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US043]
# 處理 url：/ISIN/prefix/US044
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US044]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US044]
# 處理 url：/ISIN/prefix/US045
# 處理 url：/ISIN/prefix/US0451
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0451]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0451]
# 處理 url：/ISIN/prefix/US0452
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0452]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0452]
# 處理 url：/ISIN/prefix/US0453
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0453]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0453]
# 處理 url：/ISIN/prefix/US0454
# 處理 url：/ISIN/prefix/US04541
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US04541]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US04541]
# 處理 url：/ISIN/prefix/US04542
# 處理 url：/ISIN/prefix/US045424
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US045424]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US045424]
# 處理 url：/ISIN/prefix/US04542B
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US04542B]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US04542B]
# 處理 url：/ISIN/prefix/US04545
# 獨立頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US04545]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US04545]
# 處理 url：/ISIN/prefix/US04548
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US04548]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US04548]
# 處理 url：/ISIN/prefix/US0455
# 獨立頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0455]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0455]
# 處理 url：/ISIN/prefix/US0457
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0457]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0457]
# 處理 url：/ISIN/prefix/US0459
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0459]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0459]
# 處理 url：/ISIN/prefix/US046
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US046]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US046]
# 處理 url：/ISIN/prefix/US047
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US047]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US047]
# 處理 url：/ISIN/prefix/US048
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US048]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US048]
# 處理 url：/ISIN/prefix/US049
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US049]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US049]
# 處理 url：/ISIN/prefix/US05
# 處理 url：/ISIN/prefix/US050
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US050]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US050]
# 處理 url：/ISIN/prefix/US051
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US051]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US051]
# 處理 url：/ISIN/prefix/US052
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US052]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US052]
# 處理 url：/ISIN/prefix/US053
# 處理 url：/ISIN/prefix/US0530
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0530]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0530]
# 處理 url：/ISIN/prefix/US0532
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0532]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0532]
# 處理 url：/ISIN/prefix/US0533
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0533]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0533]
# 處理 url：/ISIN/prefix/US0534
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0534]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0534]
# 處理 url：/ISIN/prefix/US0535
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0535]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0535]
# 處理 url：/ISIN/prefix/US0536
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0536]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0536]
# 處理 url：/ISIN/prefix/US0537
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0537]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0537]
# 處理 url：/ISIN/prefix/US0538
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0538]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0538]
# 處理 url：/ISIN/prefix/US054
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US054]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US054]
# 處理 url：/ISIN/prefix/US055
# 處理 url：/ISIN/prefix/US0550
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0550]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0550]
# 處理 url：/ISIN/prefix/US0551
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0551]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0551]
# 處理 url：/ISIN/prefix/US0552
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0552]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0552]
# 處理 url：/ISIN/prefix/US0553
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0553]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0553]
# 處理 url：/ISIN/prefix/US0554
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0554]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0554]
# 處理 url：/ISIN/prefix/US0555
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0555]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0555]
# 處理 url：/ISIN/prefix/US0556
# 處理 url：/ISIN/prefix/US05561
# 獨立頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US05561]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US05561]
# 處理 url：/ISIN/prefix/US05563
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US05563]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US05563]
# 處理 url：/ISIN/prefix/US05564
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US05564]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US05564]
# 處理 url：/ISIN/prefix/US05565
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US05565]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US05565]
# 處理 url：/ISIN/prefix/US05566
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US05566]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US05566]
# 處理 url：/ISIN/prefix/US05567
# 處理 url：/ISIN/prefix/US05567H
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US05567H]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US05567H]
# 處理 url：/ISIN/prefix/US05567L
# 處理 url：/ISIN/prefix/US05567L2
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US05567L2]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US05567L2]
# 處理 url：/ISIN/prefix/US05567L3
# 獨立頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US05567L3]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US05567L3]
# 處理 url：/ISIN/prefix/US05567L7
# 獨立頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US05567L7]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US05567L7]
# 處理 url：/ISIN/prefix/US05567LA
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US05567LA]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US05567LA]
# 處理 url：/ISIN/prefix/US05567LB
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US05567LB]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US05567LB]
# 處理 url：/ISIN/prefix/US05567LC
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US05567LC]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US05567LC]
# 處理 url：/ISIN/prefix/US05567LD
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US05567LD]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US05567LD]
# 處理 url：/ISIN/prefix/US05567LE
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US05567LE]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US05567LE]
# 處理 url：/ISIN/prefix/US05567LF
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US05567LF]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US05567LF]
# 處理 url：/ISIN/prefix/US05567LG
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US05567LG]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US05567LG]
# 處理 url：/ISIN/prefix/US05567LH
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US05567LH]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US05567LH]
# 處理 url：/ISIN/prefix/US05567LJ
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US05567LJ]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US05567LJ]
# 處理 url：/ISIN/prefix/US05567LK
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US05567LK]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US05567LK]
# 處理 url：/ISIN/prefix/US05567LL
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US05567LL]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US05567LL]
# 處理 url：/ISIN/prefix/US05567LM
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US05567LM]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US05567LM]
# 處理 url：/ISIN/prefix/US05567LN
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US05567LN]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US05567LN]
# 處理 url：/ISIN/prefix/US05567LP
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US05567LP]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US05567LP]
# 處理 url：/ISIN/prefix/US05567LQ
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US05567LQ]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US05567LQ]
# 處理 url：/ISIN/prefix/US05567LR
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US05567LR]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US05567LR]
# 處理 url：/ISIN/prefix/US05567LS
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US05567LS]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US05567LS]
# 處理 url：/ISIN/prefix/US05567LT
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US05567LT]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US05567LT]
# 處理 url：/ISIN/prefix/US05567LU
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US05567LU]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US05567LU]
# 處理 url：/ISIN/prefix/US05567LV
# 獨立頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US05567LV]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US05567LV]
# 處理 url：/ISIN/prefix/US05567LW
# 獨立頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US05567LW]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US05567LW]
# 處理 url：/ISIN/prefix/US05567LY
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US05567LY]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US05567LY]
# 處理 url：/ISIN/prefix/US05567LZ
# 獨立頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US05567LZ]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US05567LZ]
# 處理 url：/ISIN/prefix/US05567S
# 獨立頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US05567S]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US05567S]
# 處理 url：/ISIN/prefix/US05568
# 獨立頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US05568]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US05568]
# 處理 url：/ISIN/prefix/US0557
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0557]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0557]
# 處理 url：/ISIN/prefix/US0558
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0558]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0558]
# 處理 url：/ISIN/prefix/US0559
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0559]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0559]
# 處理 url：/ISIN/prefix/US056
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US056]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US056]
# 處理 url：/ISIN/prefix/US057
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US057]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US057]
# 處理 url：/ISIN/prefix/US058
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US058]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US058]
# 處理 url：/ISIN/prefix/US059
# 處理 url：/ISIN/prefix/US0591
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0591]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0591]
# 處理 url：/ISIN/prefix/US0594
# 處理 url：/ISIN/prefix/US05943
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US05943]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US05943]
# 處理 url：/ISIN/prefix/US05944
# 獨立頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US05944]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US05944]
# 處理 url：/ISIN/prefix/US05945
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US05945]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US05945]
# 處理 url：/ISIN/prefix/US05946
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US05946]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US05946]
# 處理 url：/ISIN/prefix/US05947
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US05947]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US05947]
# 處理 url：/ISIN/prefix/US05948
# 處理 url：/ISIN/prefix/US05948J
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US05948J]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US05948J]
# 處理 url：/ISIN/prefix/US05948K
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US05948K]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US05948K]
# 處理 url：/ISIN/prefix/US05948L
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US05948L]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US05948L]
# 處理 url：/ISIN/prefix/US05948X
# 處理 url：/ISIN/prefix/US05948XA
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US05948XA]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US05948XA]
# 處理 url：/ISIN/prefix/US05948XB
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US05948XB]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US05948XB]
# 處理 url：/ISIN/prefix/US05948XC
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US05948XC]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US05948XC]
# 處理 url：/ISIN/prefix/US05948XD
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US05948XD]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US05948XD]
# 處理 url：/ISIN/prefix/US05948XE
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US05948XE]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US05948XE]
# 處理 url：/ISIN/prefix/US05948XJ
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US05948XJ]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US05948XJ]
# 處理 url：/ISIN/prefix/US05948XK
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US05948XK]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US05948XK]
# 處理 url：/ISIN/prefix/US05948XP
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US05948XP]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US05948XP]
# 處理 url：/ISIN/prefix/US05948XS
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US05948XS]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US05948XS]
# 處理 url：/ISIN/prefix/US05948XT
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US05948XT]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US05948XT]
# 處理 url：/ISIN/prefix/US05948XZ
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US05948XZ]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US05948XZ]
# 處理 url：/ISIN/prefix/US05949
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US05949]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US05949]
# 處理 url：/ISIN/prefix/US0595
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0595]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0595]
# 處理 url：/ISIN/prefix/US0596
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0596]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0596]
# 處理 url：/ISIN/prefix/US0597
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/US0597]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/US0597]
# 處理 url：/ISIN/prefix/US0598
# ...
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU73]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU73]
# 處理 url：/ISIN/prefix/USU74
# 處理 url：/ISIN/prefix/USU740
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU740]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU740]
# 處理 url：/ISIN/prefix/USU741
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU741]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU741]
# 處理 url：/ISIN/prefix/USU742
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU742]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU742]
# 處理 url：/ISIN/prefix/USU743
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU743]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU743]
# 處理 url：/ISIN/prefix/USU744
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU744]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU744]
# 處理 url：/ISIN/prefix/USU745
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU745]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU745]
# 處理 url：/ISIN/prefix/USU746
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU746]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU746]
# 處理 url：/ISIN/prefix/USU747
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU747]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU747]
# 處理 url：/ISIN/prefix/USU748
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU748]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU748]
# 處理 url：/ISIN/prefix/USU749
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU749]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU749]
# 處理 url：/ISIN/prefix/USU75
# 處理 url：/ISIN/prefix/USU750
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU750]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU750]
# 處理 url：/ISIN/prefix/USU751
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU751]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU751]
# 處理 url：/ISIN/prefix/USU752
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU752]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU752]
# 處理 url：/ISIN/prefix/USU753
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU753]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU753]
# 處理 url：/ISIN/prefix/USU756
# 獨立頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU756]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU756]
# 處理 url：/ISIN/prefix/USU757
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU757]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU757]
# 處理 url：/ISIN/prefix/USU758
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU758]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU758]
# 處理 url：/ISIN/prefix/USU759
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU759]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU759]
# 處理 url：/ISIN/prefix/USU76
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU76]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU76]
# 處理 url：/ISIN/prefix/USU77
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU77]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU77]
# 處理 url：/ISIN/prefix/USU78
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU78]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU78]
# 處理 url：/ISIN/prefix/USU79
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU79]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU79]
# 處理 url：/ISIN/prefix/USU8
# 處理 url：/ISIN/prefix/USU80
# 處理 url：/ISIN/prefix/USU800
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU800]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU800]
# 處理 url：/ISIN/prefix/USU802
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU802]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU802]
# 處理 url：/ISIN/prefix/USU803
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU803]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU803]
# 處理 url：/ISIN/prefix/USU804
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU804]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU804]
# 處理 url：/ISIN/prefix/USU805
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU805]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU805]
# 處理 url：/ISIN/prefix/USU806
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU806]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU806]
# 處理 url：/ISIN/prefix/USU807
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU807]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU807]
# 處理 url：/ISIN/prefix/USU81
# 處理 url：/ISIN/prefix/USU810
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU810]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU810]
# 處理 url：/ISIN/prefix/USU811
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU811]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU811]
# 處理 url：/ISIN/prefix/USU812
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU812]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU812]
# 處理 url：/ISIN/prefix/USU813
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU813]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU813]
# 處理 url：/ISIN/prefix/USU814
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU814]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU814]
# 處理 url：/ISIN/prefix/USU815
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU815]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU815]
# 處理 url：/ISIN/prefix/USU816
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU816]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU816]
# 處理 url：/ISIN/prefix/USU817
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU817]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU817]
# 處理 url：/ISIN/prefix/USU818
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU818]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU818]
# 處理 url：/ISIN/prefix/USU819
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU819]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU819]
# 處理 url：/ISIN/prefix/USU82
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU82]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU82]
# 處理 url：/ISIN/prefix/USU83
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU83]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU83]
# 處理 url：/ISIN/prefix/USU84
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU84]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU84]
# 處理 url：/ISIN/prefix/USU85
# 處理 url：/ISIN/prefix/USU852
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU852]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU852]
# 處理 url：/ISIN/prefix/USU853
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU853]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU853]
# 處理 url：/ISIN/prefix/USU854
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU854]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU854]
# 處理 url：/ISIN/prefix/USU855
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU855]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU855]
# 處理 url：/ISIN/prefix/USU856
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU856]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU856]
# 處理 url：/ISIN/prefix/USU857
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU857]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU857]
# 處理 url：/ISIN/prefix/USU858
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU858]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU858]
# 處理 url：/ISIN/prefix/USU859
# 處理 url：/ISIN/prefix/USU8590
# 獨立頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU8590]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU8590]
# 處理 url：/ISIN/prefix/USU8594
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU8594]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU8594]
# 處理 url：/ISIN/prefix/USU8595
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU8595]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU8595]
# 處理 url：/ISIN/prefix/USU8596
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU8596]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU8596]
# 處理 url：/ISIN/prefix/USU8597
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU8597]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU8597]
# 處理 url：/ISIN/prefix/USU8598
# 處理 url：/ISIN/prefix/USU85985
# 處理 url：/ISIN/prefix/USU85985A
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU85985A]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU85985A]
# 處理 url：/ISIN/prefix/USU85985B
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU85985B]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU85985B]
# 處理 url：/ISIN/prefix/USU85985C
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU85985C]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU85985C]
# 處理 url：/ISIN/prefix/USU85985D
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU85985D]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU85985D]
# 處理 url：/ISIN/prefix/USU85985E
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU85985E]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU85985E]
# 處理 url：/ISIN/prefix/USU85985F
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU85985F]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU85985F]
# 處理 url：/ISIN/prefix/USU85985G
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU85985G]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU85985G]
# 處理 url：/ISIN/prefix/USU85985H
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU85985H]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU85985H]
# 處理 url：/ISIN/prefix/USU85985J
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU85985J]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU85985J]
# 處理 url：/ISIN/prefix/USU85985K
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU85985K]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU85985K]
# 處理 url：/ISIN/prefix/USU85985Q
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU85985Q]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU85985Q]
# 處理 url：/ISIN/prefix/USU85985R
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU85985R]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU85985R]
# 處理 url：/ISIN/prefix/USU85985S
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU85985S]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU85985S]
# 處理 url：/ISIN/prefix/USU85986
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU85986]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU85986]
# 處理 url：/ISIN/prefix/USU8598L
# 獨立頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU8598L]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU8598L]
# 處理 url：/ISIN/prefix/USU8598Q
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU8598Q]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU8598Q]
# 處理 url：/ISIN/prefix/USU8598T
# 獨立頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU8598T]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU8598T]
# 處理 url：/ISIN/prefix/USU8599
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU8599]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU8599]
# 處理 url：/ISIN/prefix/USU86
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU86]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU86]
# 處理 url：/ISIN/prefix/USU87
# 處理 url：/ISIN/prefix/USU872
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU872]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU872]
# 處理 url：/ISIN/prefix/USU873
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU873]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU873]
# 處理 url：/ISIN/prefix/USU875
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU875]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU875]
# 處理 url：/ISIN/prefix/USU876
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU876]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU876]
# 處理 url：/ISIN/prefix/USU877
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU877]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU877]
# 處理 url：/ISIN/prefix/USU878
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU878]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU878]
# 處理 url：/ISIN/prefix/USU879
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU879]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU879]
# 處理 url：/ISIN/prefix/USU88
# 處理 url：/ISIN/prefix/USU89
# 處理 url：/ISIN/prefix/USU890
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU890]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU890]
# 處理 url：/ISIN/prefix/USU891
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU891]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU891]
# 處理 url：/ISIN/prefix/USU892
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU892]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU892]
# 處理 url：/ISIN/prefix/USU893
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU893]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU893]
# 處理 url：/ISIN/prefix/USU894
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU894]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU894]
# 處理 url：/ISIN/prefix/USU895
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU895]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU895]
# 處理 url：/ISIN/prefix/USU896
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU896]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU896]
# 處理 url：/ISIN/prefix/USU8T
# 獨立頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU8T]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU8T]
# 處理 url：/ISIN/prefix/USU9
# 處理 url：/ISIN/prefix/USU90
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU90]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU90]
# 處理 url：/ISIN/prefix/USU91
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU91]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU91]
# 處理 url：/ISIN/prefix/USU92
# 處理 url：/ISIN/prefix/USU921
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU921]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU921]
# 處理 url：/ISIN/prefix/USU922
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU922]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU922]
# 處理 url：/ISIN/prefix/USU923
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU923]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU923]
# 處理 url：/ISIN/prefix/USU927
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU927]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU927]
# 處理 url：/ISIN/prefix/USU928
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU928]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU928]
# 處理 url：/ISIN/prefix/USU929
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU929]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU929]
# 處理 url：/ISIN/prefix/USU93
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU93]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU93]
# 處理 url：/ISIN/prefix/USU94
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU94]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU94]
# 處理 url：/ISIN/prefix/USU95
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU95]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU95]
# 處理 url：/ISIN/prefix/USU96
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU96]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU96]
# 處理 url：/ISIN/prefix/USU97
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU97]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU97]
# 處理 url：/ISIN/prefix/USU98
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU98]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU98]
# 處理 url：/ISIN/prefix/USU9T
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USU9T]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USU9T]
# 處理 url：/ISIN/prefix/USUS
# 獨立頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USUS]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USUS]
# 處理 url：/ISIN/prefix/USV
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USV]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USV]
# 處理 url：/ISIN/prefix/USW
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USW]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USW]
# 處理 url：/ISIN/prefix/USX
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USX]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USX]
# 處理 url：/ISIN/prefix/USY
# 處理 url：/ISIN/prefix/USY0
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USY0]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USY0]
# 處理 url：/ISIN/prefix/USY1
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USY1]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USY1]
# 處理 url：/ISIN/prefix/USY2
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USY2]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USY2]
# 處理 url：/ISIN/prefix/USY3
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USY3]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USY3]
# 處理 url：/ISIN/prefix/USY4
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USY4]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USY4]
# 處理 url：/ISIN/prefix/USY5
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USY5]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USY5]
# 處理 url：/ISIN/prefix/USY6
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USY6]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USY6]
# 處理 url：/ISIN/prefix/USY7
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USY7]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USY7]
# 處理 url：/ISIN/prefix/USY8
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USY8]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USY8]
# 處理 url：/ISIN/prefix/USY9
# 目標頁面，進行爬取：[http://www.isinlei.com/ISIN/prefix/USY9]
# 完成爬取頁面：[http://www.isinlei.com/ISIN/prefix/USY9]
# 花費時間： 9412.220s 2020-04-12 03:17:50

# %%
excel_file.save('prefix_US.xlsx')
